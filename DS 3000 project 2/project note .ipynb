# %%
#data cleaning
import pandas as pd
import numpy as np

fighter_info = pd.read_csv("fight_info.csv")
reach_df = pd.read_csv("reaches.csv")

fighter_info["Reach"] = reach_df["0"]

fighter_info.to_csv("fight_info_final.csv")

fighter_info_final = pd.read_csv("fighter_info_final copy.csv")

fight_info = pd.read_csv("fight_info_dataframe.csv")


#shows all fights not separated by event
fight_info_per_row_temp = fight_info[["Fights", "Winners", "Methods"]]

fight_info_per_row_temp
# Out:
#                                                 Fights  \
# 0    ['Zabit Magomedsharipov vs Calvin Kattar', 'Al...
# 1    ['Jorge Masvidal vs Nate Diaz', 'Darren Till v...
# 2    ['Demian Maia vs Ben Askren', 'Stevie Ray vs M...
# 3    ['Dominick Reyes vs Chris Weidman', 'Yair Rodr...
# 4    ['Joanna Jedrzejczyk vs Michelle Waterson', 'C...
# 5    ['Israel Adesanya vs Robert Whittaker', 'Dan H...
# 6    ['Jared Cannonier vs Jack Hermansson', 'Mark M...
# 7    ['Yair Rodriguez vs Jeremy Stephens', 'Carla E...
# 8    ['Justin Gaethje vs Donald Cerrone', 'Glover T...
# 9    ['Khabib Nurmagomedov vs Dustin Poirier', 'Pau...
# 10   ['Weili Zhang vs Jessica Andrade', 'Jingliang ...
# 11   ['Stipe Miocic vs Daniel Cormier', 'Nate Diaz ...
# 12   ['Valentina Shevchenko vs Liz Carmouche', 'Vic...
# 13   ['Colby Covington vs Robbie Lawler', 'Jim Mill...
# 14   ['Max Holloway vs Frankie Edgar', 'Cris Cyborg...
# 15   ['Leon Edwards vs Rafael Dos Anjos', 'Walt Har...
# ...

# %%
fight_info_per_row = pd.DataFrame()

fight_list = []
str_test = ""

for i in range(0,501):
    fights = fight_info_per_row_temp["Fights"][i]
    #str_test += str(fight)
    winners = fight_info_per_row_temp["Winners"][i]
    methods = fight_info_per_row_temp["Methods"][i]
    num_fights = len(fights)
    str_test+=str(len(fights)) + " "
    
#print(str_test)
print(len(fight_info_per_row_temp["Fights"][0]))
# Out:
# 493

# %%
fight_info_per_row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5600b2f06aba> in <module>()
# ----> 1 fight_info_per_row
#
# NameError: name 'fight_info_per_row' is not defined
